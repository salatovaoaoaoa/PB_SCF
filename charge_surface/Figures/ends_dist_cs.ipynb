# %%
import sys
sys.path.append('/home/tpopova/prj/PB_SCF/charge_surface/py_files')
from flatQuenchedBrush import flatQuenchedBrush
from create_in import create_in
from out_reader import out_reader
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import get_cmap

# %%
N = 100

S_namics = 150

alpha = 0.5

Cs_range = [0.0005, 0.001, 0.003, 0.007, 0.01]
surf_val_0 = 0
surf_val = 0.15

chi = 0.5
chi_surf = -0.3

# %%
profiles_val_0 = {}
for cs in Cs_range:
    # Создать SCF файл
    file_name_pro = create_in(
    template_surf_charge='/home/tpopova/prj/PB_SCF/charge_surface/scf_templates/flat_brush_surf.in',
    range_param='cs',
    min_val=0.1,
    max_val=0.1,
    Cs=cs,
    chi=chi,
    chi_surf=chi_surf,
    N_layers=N,
    N=N,
    S=S_namics,
    alpha=alpha,
    surf_val=surf_val_0
    )

    # парсим профили
    psi, phi_brush, phi_end_brush = out_reader(file_names = file_name_pro)
    
    coord = np.arange(N)
    
    profiles_val_0[cs] = (coord, phi_end_brush)
# Out:
# Problem nr 1 out of 1
# The program is compiled for the use of 'long double' while 'overflow_protection' is not requested for;
# 1. Turn on 'overflow_protection'.
# 2. Compile progrem without the #define 'LongReal' in namics.h.
# ...
# NEWTON has been notified.
# Your guess:it =  0  E = 1.466949e+00 |g| = 2.895213e+00 alpha = 1.000000e+00
# hessian scaling: 0.33968
# it =  1  E = 1.368828e+00 |g| = 2.772945e+00 alpha = 1.345398e-01
# it =  2  E = 3.315767e+00 |g| = 2.911784e+00 alpha = 2.260570e-02
# it =  3  E = 1.482846e+01 |g| = 2.981556e+00 alpha = 1.238903e-03
# it =  4  E = 8.906235e+00 |g| = 2.936308e+00 alpha = 3.138808e-03
# it =  5  E = 1.140688e+01 |g| = 3.022046e+00 alpha = 1.863256e-03
# it =  6  E = 7.473266e+00 |g| = 3.039898e+00 alpha = 4.056205e-03
# it =  7  E = 7.918332e+00 |g| = 3.004948e+00 alpha = 3.333322e-03
# it =  8  E = 8.202773e+00 |g| = 3.012115e+00 alpha = 2.917192e-03
# it =  9  E = 9.197637e+00 |g| = 2.986777e+00 alpha = 2.163358e-03
# ...

# %%
profiles_val = {}
for cs in Cs_range:
    # Создать SCF файл
    file_name_pro = create_in(
    template_surf_charge='/home/tpopova/prj/PB_SCF/charge_surface/scf_templates/flat_brush_surf.in',
    range_param='Cs',
    min_val=0.1,
    max_val=0.1,
    Cs=cs,
    chi=chi,
    chi_surf=chi_surf,
    N_layers=N,
    N=N,
    S=S_namics,
    alpha=alpha,
    surf_val=surf_val
    )

    # парсим профили
    psi, phi_brush, phi_end_brush = out_reader(file_names = file_name_pro)
    
    coord = np.arange(N)
    
    profiles_val[cs] = (coord, phi_end_brush)
# Out:
# Problem nr 1 out of 1
# The program is compiled for the use of 'long double' while 'overflow_protection' is not requested for;
# 1. Turn on 'overflow_protection'.
# 2. Compile progrem without the #define 'LongReal' in namics.h.
# ...
# NEWTON has been notified.
# Your guess:it =  0  E = 1.457738e+00 |g| = 2.866358e+00 alpha = 1.000000e+00
# hessian scaling: 0.355498
# it =  1  E = 1.358229e+00 |g| = 2.737226e+00 alpha = 1.348875e-01
# it =  2  E = 2.997404e+00 |g| = 2.780277e+00 alpha = 2.634707e-02
# it =  3  E = 4.248815e+00 |g| = 2.864158e+00 alpha = 1.281927e-02
# it =  4  E = 6.237019e+00 |g| = 2.726652e+00 alpha = 5.297339e-03
# it =  5  E = 3.645067e+00 |g| = 2.707042e+00 alpha = 1.436442e-02
# it =  6  E = 4.510832e+00 |g| = 2.690191e+00 alpha = 8.724912e-03
# it =  7  E = 4.160029e+00 |g| = 2.653997e+00 alpha = 9.526049e-03
# it =  8  E = 4.366227e+00 |g| = 2.642595e+00 alpha = 8.122822e-03
# it =  9  E = 4.225631e+00 |g| = 2.612575e+00 alpha = 8.117892e-03
# ...

# %%
# Построение графиков
plt.figure(figsize=(12, 8))
color_map = get_cmap("plasma")

# Первый набор кривых
for i, (cs, (coord, phi_end_brush)) in enumerate(profiles_val_0.items()):
    color = color_map(i / len(Cs_range))
    plt.plot(coord, phi_end_brush, label=f"val = 0, Cs = {cs}", linewidth=3, alpha = 0.7, color=color, linestyle="-")

# Второй набор кривых
for i, (cs, (coord, phi_end_brush)) in enumerate(profiles_val.items()):
    color = color_map((i + 0.5) / len(Cs_range))
    plt.plot(coord, phi_end_brush, label=f"val = 0.15, Cs = {cs}", linewidth=3, color=color, linestyle="--")

# Настройка визуализации
plt.xlabel("z", fontsize=18, labelpad=10)
plt.ylabel("$\phi(z)$", fontsize=18, labelpad=10)
plt.legend(fontsize=12, title=f"$N = {N}, S = {S_namics}, val = 0/0.15, \chi = {chi}$", title_fontsize=14, loc="upper right")
plt.tight_layout()
plt.ylim(0, 0.0003)
plt.xlim(0, 80)

# Удаление лишних рамок
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_color("#333333")
plt.gca().spines["bottom"].set_color("#333333")

# Сохранение и отображение графика
plt.savefig('end_dist_var_cs_N_100.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# <>:18: SyntaxWarning: invalid escape sequence '\c'
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# <>:18: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_2201521/462766924.py:17: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel("$\phi(z)$", fontsize=18, labelpad=10)
# /tmp/ipykernel_2201521/462766924.py:18: SyntaxWarning: invalid escape sequence '\c'
#   plt.legend(fontsize=12, title=f"$N = {N}, S = {S_namics}, val = 0/0.15, \chi = {chi}$", title_fontsize=14, loc="upper right")
# /tmp/ipykernel_2201521/462766924.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = get_cmap("plasma")
